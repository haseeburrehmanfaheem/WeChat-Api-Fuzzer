# %%
import pandas as pd

# %%
df = pd.read_csv('invariantApis.csv')
df
# Out:
#                                 Name     Return Type  \
# 0            onLivePusherBGMProgress             NaN
# 1                   onAddToFavorites             NaN
# 2           showNavigationBarLoading  <Primordial,V>
# 3                         onMusicEnd             NaN
# 4                           saveFile  <Primordial,V>
# ...                              ...             ...
# 1022         openChannelsOrderCenter  <Primordial,V>
# 1023         openWCPayLQTDepositPlan  <Primordial,V>
# 1024    startFacialRecognitionVerify  <Primordial,V>
# 1025                   shareTimeline  <Primordial,V>
# 1026  enableLocationUpdateBackground  <Primordial,V>
#
#                                              Class Name Method Name  \
# 0                                 <Application,Lgt0/s0>         NaN
# 1     <Application,Lcom/tencent/mm/plugin/appbrand/m...         NaN
# 2                                 <Application,Lzt0/s1>           u
# 3     <Application,Lcom/tencent/mm/plugin/appbrand/j...         NaN
# 4     <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# ...                                                 ...         ...
# 1022  <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# 1023  <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# 1024  <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# 1025  <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# 1026  <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
#
#                                             Super Class  Number of Args  \
# 0                                                   NaN               0
# 1                                                   NaN               0
# 2     <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 3                                                   NaN               0
# 4     <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# ...                                                 ...             ...
# 1022  <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 1023  <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 1024  <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 1025  <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 1026  <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
#
#                                          Original Class
# 0                                 <Application,Lgt0/s0>
# 1     <Application,Lcom/tencent/mm/plugin/appbrand/m...
# 2                                 <Application,Lzt0/s1>
# 3     <Application,Lcom/tencent/mm/plugin/appbrand/j...
# 4     <Application,Lcom/tencent/mm/plugin/appbrand/j...
# ...                                                 ...
# 1022  <Application,Lcom/tencent/mm/plugin/appbrand/j...
# 1023  <Application,Lcom/tencent/mm/plugin/appbrand/j...
# 1024  <Application,Lcom/tencent/mm/plugin/appbrand/j...
# 1025  <Application,Lcom/tencent/mm/plugin/appbrand/j...
# 1026  <Application,Lcom/tencent/mm/plugin/appbrand/j...
#
# [1027 rows x 7 columns]

# %% [markdown]
# drop method not found and method name != u

# %%
# drop null values row where MethodName is null 
df = df.dropna(subset=['Method Name'])
df = df[df['Method Name'] == 'u']
df
# Out:
#                                 Name     Return Type  \
# 2           showNavigationBarLoading  <Primordial,V>
# 4                           saveFile  <Primordial,V>
# 5                        openSetting  <Primordial,V>
# 6               removeXWebLivePlayer  <Primordial,V>
# 7                     searchContacts  <Primordial,V>
# ...                              ...             ...
# 1022         openChannelsOrderCenter  <Primordial,V>
# 1023         openWCPayLQTDepositPlan  <Primordial,V>
# 1024    startFacialRecognitionVerify  <Primordial,V>
# 1025                   shareTimeline  <Primordial,V>
# 1026  enableLocationUpdateBackground  <Primordial,V>
#
#                                              Class Name Method Name  \
# 2                                 <Application,Lzt0/s1>           u
# 4     <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# 5     <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# 6     <Application,Lcom/tencent/mm/plugin/appbrand/e...           u
# 7     <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# ...                                                 ...         ...
# 1022  <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# 1023  <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# 1024  <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# 1025  <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# 1026  <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
#
#                                             Super Class  Number of Args  \
# 2     <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 4     <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 5     <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 6     <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 7     <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# ...                                                 ...             ...
# 1022  <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 1023  <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 1024  <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 1025  <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 1026  <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
#
#                                          Original Class
# 2                                 <Application,Lzt0/s1>
# 4     <Application,Lcom/tencent/mm/plugin/appbrand/j...
# 5     <Application,Lcom/tencent/mm/plugin/appbrand/j...
# 6                                  <Application,Ldw0/h>
# 7     <Application,Lcom/tencent/mm/plugin/appbrand/j...
# ...                                                 ...
# 1022  <Application,Lcom/tencent/mm/plugin/appbrand/j...
# 1023  <Application,Lcom/tencent/mm/plugin/appbrand/j...
# 1024  <Application,Lcom/tencent/mm/plugin/appbrand/j...
# 1025  <Application,Lcom/tencent/mm/plugin/appbrand/j...
# 1026  <Application,Lcom/tencent/mm/plugin/appbrand/j...
#
# [707 rows x 7 columns]

# %% [markdown]
# Superclass should be <Application,Lcom/tencent/mm/plugin/appbrand/jsapi/f>

# %%
df = df[df['Super Class'] == '<Application,Lcom/tencent/mm/plugin/appbrand/jsapi/f>']
df
# Out:
#                                 Name     Return Type  \
# 2           showNavigationBarLoading  <Primordial,V>
# 4                           saveFile  <Primordial,V>
# 5                        openSetting  <Primordial,V>
# 6               removeXWebLivePlayer  <Primordial,V>
# 7                     searchContacts  <Primordial,V>
# ...                              ...             ...
# 1022         openChannelsOrderCenter  <Primordial,V>
# 1023         openWCPayLQTDepositPlan  <Primordial,V>
# 1024    startFacialRecognitionVerify  <Primordial,V>
# 1025                   shareTimeline  <Primordial,V>
# 1026  enableLocationUpdateBackground  <Primordial,V>
#
#                                              Class Name Method Name  \
# 2                                 <Application,Lzt0/s1>           u
# 4     <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# 5     <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# 6     <Application,Lcom/tencent/mm/plugin/appbrand/e...           u
# 7     <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# ...                                                 ...         ...
# 1022  <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# 1023  <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# 1024  <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# 1025  <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
# 1026  <Application,Lcom/tencent/mm/plugin/appbrand/j...           u
#
#                                             Super Class  Number of Args  \
# 2     <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 4     <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 5     <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 6     <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 7     <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# ...                                                 ...             ...
# 1022  <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 1023  <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 1024  <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 1025  <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
# 1026  <Application,Lcom/tencent/mm/plugin/appbrand/j...               4
#
#                                          Original Class
# 2                                 <Application,Lzt0/s1>
# 4     <Application,Lcom/tencent/mm/plugin/appbrand/j...
# 5     <Application,Lcom/tencent/mm/plugin/appbrand/j...
# 6                                  <Application,Ldw0/h>
# 7     <Application,Lcom/tencent/mm/plugin/appbrand/j...
# ...                                                 ...
# 1022  <Application,Lcom/tencent/mm/plugin/appbrand/j...
# 1023  <Application,Lcom/tencent/mm/plugin/appbrand/j...
# 1024  <Application,Lcom/tencent/mm/plugin/appbrand/j...
# 1025  <Application,Lcom/tencent/mm/plugin/appbrand/j...
# 1026  <Application,Lcom/tencent/mm/plugin/appbrand/j...
#
# [707 rows x 7 columns]

# %%
names_all = df["Name"]

# convert the series into an array
names_all = names_all.values
names_all = set(names_all)
len(names_all)
# print duplciate names in names_all
# import collections
# print([item for item, count in collections.Counter(names_all).items() if count > 1])
# Out:
# 664

# %% [markdown]
# Documented APIs

# %%
f = open("docAPIs.txt", "r")
names_doc = f.read().splitlines()
f.close()
# len(names_doc)
# names_doc = set(names_doc)
len(names_doc)
# Out:
# 1280

# %%
# print all names that are present in names_all but not present in names_doc
undocumented = []
for name in names_all:
    if name not in names_doc:
        undocumented.append(name)

len(undocumented)
# Out:
# 491

# %%
# write the undocumented APIs to a file
f = open("undocumentedAPIsStrict.txt", "w")
for name in undocumented:
    f.write(name + "\n")
f.close()
